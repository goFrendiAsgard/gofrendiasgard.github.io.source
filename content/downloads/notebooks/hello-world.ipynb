# %% [markdown]
# Following is a simple python code

# %%
print("Hello world")
# Out:
# Hello world

# %% [markdown]
# Now, I am playing with $L_AT_EX$, cool huh? Next, let me show you a sine graph

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0,7,100)
y = np.sin(x)

fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.plot(x,y)
plt.show()
